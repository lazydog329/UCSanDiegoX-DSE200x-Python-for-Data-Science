# %% [markdown]
# Below is how we calaulate the number of seconds in a leap yeat.

# %%
366 * 24 * 60 * 60
# Out:
# 31622400

# %%
_ / 1000000 # _ refer to the output of the last cell executed
# Out:
# 31.6224

# %%
x = 4 + 3

# %%
print (x)
# Out:
# 7

# %% [markdown]
# # This is a mardown cell.
# ## This is heading 2.
# ### This is heading 3.
#
# Hi!
#
# * One fish
# * Two fishes
# * Red fish
# * Blue fish
#
# **example text** \bold
#
# *example text* \斜體

# %% [markdown]
# This is a **Latex** equation
#
# $\int_0^\infty x^{-\alpha}$

# %%
# %matplotlib inline
from matplotlib.pyplot import plot
plot([0,1,0,1])

# %% [markdown]
# This is a plot using matplotlib of a vector.
