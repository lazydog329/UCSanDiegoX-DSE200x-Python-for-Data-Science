# %% [markdown]
# # Twitter data
#
# ## Copyright and Licensing
#
# You are free to use or adapt this notebook for any purpose you'd like. However, please respect the [Simplified BSD License](https://github.com/ptwobrussell/Mining-the-Social-Web-2nd-Edition/blob/master/LICENSE.txt) that governs its use.

# %% [markdown]
# # Twitter API Access
#
# Twitter implements OAuth 1.0A as its standard authentication mechanism, and in order to use it to make requests to Twitter's API, you'll need to go to https://dev.twitter.com/apps and create a sample application.
#
# Choose any name for your application, write a description and use `http://google.com` for the website.
#
# Under **Key and Access Tokens**, there are four primary identifiers you'll need to note for an OAuth 1.0A workflow:
# * consumer key,
# * consumer secret,
# * access token, and
# * access token secret (Click on Create Access Token to create those).
#
# Note that you will need an ordinary Twitter account in order to login, create an app, and get these credentials.

# %% [markdown]
# The first time you execute the notebook, add all credentials so that you can save them in the `pkl` file, then you can remove the secret keys from the notebook because they will just be loaded from the `pkl` file.
#
# The `pkl` file contains sensitive information that can be used to take control of your twitter acccount, **do not share it**.

# %%
import pickle
import os

# %%
if not os.path.exists('secret_twitter_credentials.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = 'kqLnYdYhzGhkUYk7FkDOcSNAj'
    Twitter['Consumer Secret'] = 'KI0CzlOzarCKF2RMq5Pd3L3JvLJsLlnFofwVawF2kUroeBrPFB'
    Twitter['Access Token'] = '1067767943944036353-oszJolzqwKniO2haVACrTsoKOOjiZR'
    Twitter['Access Token Secret'] = '1sF2Awr6Ez3vVFDXSoKXyrm0GgcSIFkqwmkn0Ju5zL2gT'
    with open('secret_twitter_credentials.pkl','wb') as f:
        pickle.dump(Twitter, f)
else:
    Twitter=pickle.load(open('secret_twitter_credentials.pkl','rb'))

# %% [markdown]
# Install the `twitter` package to interface with the Twitter API

# %%
# !pip install twitter
# Out:
# Requirement already satisfied: twitter in /Users/johnny/anaconda3/lib/python3.6/site-packages (1.18.0)

# %% [markdown]
# ## Example 1. Authorizing an application to access Twitter account data

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# Nothing to see by displaying twitter_api except that it's now a
# defined variable

print(twitter_api)
# Out:
# <twitter.api.Twitter object at 0x1112177b8>

# %% [markdown]
# ## Example 2. Retrieving trends

# %% [markdown]
# Twitter identifies locations using the Yahoo! Where On Earth ID.
#
# The Yahoo! Where On Earth ID for the entire world is 1.
# See https://dev.twitter.com/docs/api/1.1/get/trends/place and
# http://developer.yahoo.com/geo/geoplanet/
#
# look at the BOSS placefinder here: https://developer.yahoo.com/boss/placefinder/

# %%
WORLD_WOE_ID = 1
US_WOE_ID = 23424977

# %% [markdown]
# Look for the WOEID for [Los Angeles](http://woeid.rosselliot.co.nz/lookup/los%20angeles)
#
# You can change it to another location.

# %%
LOCAL_WOE_ID= 2442047

# Prefix ID with the underscore for query string parameterization.
# Without the underscore, the twitter package appends the ID value
# to the URL itself as a special case keyword argument.

world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)
us_trends = twitter_api.trends.place(_id=US_WOE_ID)
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)

# %%
world_trends[:2]
# Out:
# [{'as_of': '2018-12-01T00:27:54Z',
#   'created_at': '2018-12-01T00:21:44Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}],
#   'trends': [{'name': '#ThankUNextVideo',
#     'promoted_content': None,
#     'query': '%23ThankUNextVideo',
#     'tweet_volume': 544478,
#     'url': 'http://twitter.com/search?q=%23ThankUNextVideo'},
#    {'name': 'Colón',
#     'promoted_content': None,
#     'query': 'Col%C3%B3n',
#     'tweet_volume': 58930,
#     'url': 'http://twitter.com/search?q=Col%C3%B3n'},
#    {'name': '#LateLateToyShow',
#     'promoted_content': None,
#     'query': '%23LateLateToyShow',
#     'tweet_volume': 51511,
#     'url': 'http://twitter.com/search?q=%23LateLateToyShow'},
#    {'name': 'Kareem Hunt',
#     'promoted_content': None,
#     'query': '%22Kareem+Hunt%22',
#     'tweet_volume': 66940,
#     'url': 'http://twitter.com/search?q=%22Kareem+Hunt%22'},
#    {'name': '#اوصف_شعورك_بكلمه',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%88%D8%B5%D9%81_%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%A8%D9%83%D9%84%D9%85%D9%87',
#     'tweet_volume': 12442,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%88%D8%B5%D9%81_%D8%B4%D8%B9%D9%88%D8%B1%D9%83_%D8%A8%D9%83%D9%84%D9%85%D9%87'},
#    {'name': '#TCMS10',
#     'promoted_content': None,
#     'query': '%23TCMS10',
#     'tweet_volume': 10800,
#     'url': 'http://twitter.com/search?q=%23TCMS10'},
#    {'name': 'Alaska',
#     'promoted_content': None,
#     'query': 'Alaska',
#     'tweet_volume': 220164,
#     'url': 'http://twitter.com/search?q=Alaska'},
#    {'name': '#هل_تنصحون_بالزواج_المبكر',
#     'promoted_content': None,
#     'query': '%23%D9%87%D9%84_%D8%AA%D9%86%D8%B5%D8%AD%D9%88%D9%86_%D8%A8%D8%A7%D9%84%D8%B2%D9%88%D8%A7%D8%AC_%D8%A7%D9%84%D9%85%D8%A8%D9%83%D8%B1',
#     'tweet_volume': 25307,
#     'url': 'http://twitter.com/search?q=%23%D9%87%D9%84_%D8%AA%D9%86%D8%B5%D8%AD%D9%88%D9%86_%D8%A8%D8%A7%D9%84%D8%B2%D9%88%D8%A7%D8%AC_%D8%A7%D9%84%D9%85%D8%A8%D9%83%D8%B1'},
#    {'name': 'Anchorage',
#     'promoted_content': None,
#     'query': 'Anchorage',
#     'tweet_volume': 155357,
#     'url': 'http://twitter.com/search?q=Anchorage'},
#    {'name': 'Julio Bocca',
#     'promoted_content': None,
#     'query': '%22Julio+Bocca%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Julio+Bocca%22'},
#    {'name': 'Yan Gomes',
#     'promoted_content': None,
#     'query': '%22Yan+Gomes%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Yan+Gomes%22'},
#    {'name': 'Sam Gyimah',
#     'promoted_content': None,
#     'query': '%22Sam+Gyimah%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Sam+Gyimah%22'},
#    {'name': 'Flavia Palmiero',
#     'promoted_content': None,
#     'query': '%22Flavia+Palmiero%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Flavia+Palmiero%22'},
#    {'name': 'Pinilla',
#     'promoted_content': None,
#     'query': 'Pinilla',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=Pinilla'},
#    {'name': 'Tim Means',
#     'promoted_content': None,
#     'query': '%22Tim+Means%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Tim+Means%22'},
#    {'name': 'Matías Suárez',
#     'promoted_content': None,
#     'query': '%22Mat%C3%ADas+Su%C3%A1rez%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Mat%C3%ADas+Su%C3%A1rez%22'},
#    {'name': 'Wilmer Flores',
#     'promoted_content': None,
#     'query': '%22Wilmer+Flores%22',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%22Wilmer+Flores%22'},
#    {'name': 'Amber Guyger',
#     'promoted_content': None,
#     'query': '%22Amber+Guyger%22',
#     'tweet_volume': 18511,
#     'url': 'http://twitter.com/search?q=%22Amber+Guyger%22'},
#    {'name': '#AskMeek',
#     'promoted_content': None,
#     'query': '%23AskMeek',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AskMeek'},
#    {'name': '#HarryPotterEnCuatro',
#     'promoted_content': None,
#     'query': '%23HarryPotterEnCuatro',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HarryPotterEnCuatro'},
#    {'name': '#ViernesDeEliminacion',
#     'promoted_content': None,
#     'query': '%23ViernesDeEliminacion',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ViernesDeEliminacion'},
#    {'name': '#BalanceTonPost',
#     'promoted_content': None,
#     'query': '%23BalanceTonPost',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23BalanceTonPost'},
#    {'name': '#PagaráPremiumSuMadre',
#     'promoted_content': None,
#     'query': '%23Pagar%C3%A1PremiumSuMadre',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23Pagar%C3%A1PremiumSuMadre'},
#    {'name': '#AMLOFest',
#     'promoted_content': None,
#     'query': '%23AMLOFest',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AMLOFest'},
#    {'name': '#MilenioLive',
#     'promoted_content': None,
#     'query': '%23MilenioLive',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23MilenioLive'},
#    {'name': '#TheVoiceKids',
#     'promoted_content': None,
#     'query': '%23TheVoiceKids',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23TheVoiceKids'},
#    {'name': '#قمه_لقاء_محمد_بن_سلمان',
#     'promoted_content': None,
#     'query': '%23%D9%82%D9%85%D9%87_%D9%84%D9%82%D8%A7%D8%A1_%D9%85%D8%AD%D9%85%D8%AF_%D8%A8%D9%86_%D8%B3%D9%84%D9%85%D8%A7%D9%86',
#     'tweet_volume': 28726,
#     'url': 'http://twitter.com/search?q=%23%D9%82%D9%85%D9%87_%D9%84%D9%82%D8%A7%D8%A1_%D9%85%D8%AD%D9%85%D8%AF_%D8%A8%D9%86_%D8%B3%D9%84%D9%85%D8%A7%D9%86'},
#    {'name': '#propagandalive',
#     'promoted_content': None,
#     'query': '%23propagandalive',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23propagandalive'},
#    {'name': '#CrownPrinceInG20',
#     'promoted_content': None,
#     'query': '%23CrownPrinceInG20',
#     'tweet_volume': 284101,
#     'url': 'http://twitter.com/search?q=%23CrownPrinceInG20'},
#    {'name': '#EnDiciembreMeEspera',
#     'promoted_content': None,
#     'query': '%23EnDiciembreMeEspera',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23EnDiciembreMeEspera'},
#    {'name': '#G20Summit2018',
#     'promoted_content': None,
#     'query': '%23G20Summit2018',
#     'tweet_volume': 32196,
#     'url': 'http://twitter.com/search?q=%23G20Summit2018'},
#    {'name': '#ادعم_جروس',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D8%AF%D8%B9%D9%85_%D8%AC%D8%B1%D9%88%D8%B3',
#     'tweet_volume': 91014,
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D8%AF%D8%B9%D9%85_%D8%AC%D8%B1%D9%88%D8%B3'},
#    {'name': '#平ジェネFOREVER',
#     'promoted_content': None,
#     'query': '%23%E5%B9%B3%E3%82%B8%E3%82%A7%E3%83%8DFOREVER',
#     'tweet_volume': 13458,
#     'url': 'http://twitter.com/search?q=%23%E5%B9%B3%E3%82%B8%E3%82%A7%E3%83%8DFOREVER'},
#    {'name': '#ديسمبر',
#     'promoted_content': None,
#     'query': '%23%D8%AF%D9%8A%D8%B3%D9%85%D8%A8%D8%B1',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23%D8%AF%D9%8A%D8%B3%D9%85%D8%A8%D8%B1'},
#    {'name': '#HotWheelsSebas',
#     'promoted_content': None,
#     'query': '%23HotWheelsSebas',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23HotWheelsSebas'},
#    {'name': '#SchleFaZ',
#     'promoted_content': None,
#     'query': '%23SchleFaZ',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23SchleFaZ'},
#    {'name': '#GrahamNorton',
#     'promoted_content': None,
#     'query': '%23GrahamNorton',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23GrahamNorton'},
#    {'name': '#RomComMyLife',
#     'promoted_content': None,
#     'query': '%23RomComMyLife',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23RomComMyLife'},
#    {'name': '#CARWOL',
#     'promoted_content': None,
#     'query': '%23CARWOL',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23CARWOL'},
#    {'name': '#scherziaparte',
#     'promoted_content': None,
#     'query': '%23scherziaparte',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23scherziaparte'},
#    {'name': '#RememberSKAM',
#     'promoted_content': None,
#     'query': '%23RememberSKAM',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23RememberSKAM'},
#    {'name': '#ChadwickRenuncia',
#     'promoted_content': None,
#     'query': '%23ChadwickRenuncia',
#     'tweet_volume': 18408,
#     'url': 'http://twitter.com/search?q=%23ChadwickRenuncia'},
#    {'name': '#UltimoViernesDeMesY',
#     'promoted_content': None,
#     'query': '%23UltimoViernesDeMesY',
#     'tweet_volume': 13294,
#     'url': 'http://twitter.com/search?q=%23UltimoViernesDeMesY'},
#    {'name': '#AsAventurasDePoliana143',
#     'promoted_content': None,
#     'query': '%23AsAventurasDePoliana143',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23AsAventurasDePoliana143'},
#    {'name': '#ElMandamas',
#     'promoted_content': None,
#     'query': '%23ElMandamas',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ElMandamas'},
#    {'name': '#UnCuentoInfantilConDuque',
#     'promoted_content': None,
#     'query': '%23UnCuentoInfantilConDuque',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23UnCuentoInfantilConDuque'},
#    {'name': '#SagerStrong',
#     'promoted_content': None,
#     'query': '%23SagerStrong',
#     'tweet_volume': 11406,
#     'url': 'http://twitter.com/search?q=%23SagerStrong'},
#    {'name': '#ウルトラマンルーブ',
#     'promoted_content': None,
#     'query': '%23%E3%82%A6%E3%83%AB%E3%83%88%E3%83%A9%E3%83%9E%E3%83%B3%E3%83%AB%E3%83%BC%E3%83%96',
#     'tweet_volume': 12787,
#     'url': 'http://twitter.com/search?q=%23%E3%82%A6%E3%83%AB%E3%83%88%E3%83%A9%E3%83%9E%E3%83%B3%E3%83%AB%E3%83%BC%E3%83%96'},
#    {'name': '#bakeoffitalia',
#     'promoted_content': None,
#     'query': '%23bakeoffitalia',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23bakeoffitalia'},
#    {'name': '#ASSEFCN',
#     'promoted_content': None,
#     'query': '%23ASSEFCN',
#     'tweet_volume': None,
#     'url': 'http://twitter.com/search?q=%23ASSEFCN'}]}]

# %%
trends=local_trends
print(type(trends))
print(list(trends[0].keys()))
print(trends[0]['trends'])
# Out:
# <class 'twitter.api.TwitterListResponse'>
# ['trends', 'as_of', 'created_at', 'locations']
# [{'name': '#ThankUNextVideo', 'url': 'http://twitter.com/search?q=%23ThankUNextVideo', 'promoted_content': None, 'query': '%23ThankUNextVideo', 'tweet_volume': 544478}, {'name': 'Ariana Grande', 'url': 'http://twitter.com/search?q=%22Ariana+Grande%22', 'promoted_content': None, 'query': '%22Ariana+Grande%22', 'tweet_volume': 239785}, {'name': 'Kareem Hunt', 'url': 'http://twitter.com/search?q=%22Kareem+Hunt%22', 'promoted_content': None, 'query': '%22Kareem+Hunt%22', 'tweet_volume': 66940}, {'name': 'Nick Nolte', 'url': 'http://twitter.com/search?q=%22Nick+Nolte%22', 'promoted_content': None, 'query': '%22Nick+Nolte%22', 'tweet_volume': None}, {'name': '#AskMeek', 'url': 'http://twitter.com/search?q=%23AskMeek', 'promoted_content': None, 'query': '%23AskMeek', 'tweet_volume': None}, {'name': 'Anchorage', 'url': 'http://twitter.com/search?q=Anchorage', 'promoted_content': None, 'query': 'Anchorage', 'tweet_volume': 155357}, {'name': 'Yan Gomes', 'url': 'http://twitter.com/search?q=%22Yan+Gomes%22', 'promoted_content': None, 'query': '%22Yan+Gomes%22', 'tweet_volume': None}, {'name': '#AlaskaEarthquake', 'url': 'http://twitter.com/search?q=%23AlaskaEarthquake', 'promoted_content': None, 'query': '%23AlaskaEarthquake', 'tweet_volume': None}, {'name': 'Wilmer Flores', 'url': 'http://twitter.com/search?q=%22Wilmer+Flores%22', 'promoted_content': None, 'query': '%22Wilmer+Flores%22', 'tweet_volume': None}, {'name': '#SagerStrong', 'url': 'http://twitter.com/search?q=%23SagerStrong', 'promoted_content': None, 'query': '%23SagerStrong', 'tweet_volume': 11406}, {'name': '#RomComMyLife', 'url': 'http://twitter.com/search?q=%23RomComMyLife', 'promoted_content': None, 'query': '%23RomComMyLife', 'tweet_volume': None}, {'name': 'Amber Guyger', 'url': 'http://twitter.com/search?q=%22Amber+Guyger%22', 'promoted_content': None, 'query': '%22Amber+Guyger%22', 'tweet_volume': 18511}, {'name': 'Tim Means', 'url': 'http://twitter.com/search?q=%22Tim+Means%22', 'promoted_content': None, 'query': '%22Tim+Means%22', 'tweet_volume': None}, {'name': 'Tornado Watch', 'url': 'http://twitter.com/search?q=%22Tornado+Watch%22', 'promoted_content': None, 'query': '%22Tornado+Watch%22', 'tweet_volume': None}, {'name': 'Spencer Ware', 'url': 'http://twitter.com/search?q=%22Spencer+Ware%22', 'promoted_content': None, 'query': '%22Spencer+Ware%22', 'tweet_volume': None}, {'name': 'wayne estopinal', 'url': 'http://twitter.com/search?q=%22wayne+estopinal%22', 'promoted_content': None, 'query': '%22wayne+estopinal%22', 'tweet_volume': None}, {'name': 'Brenda Snipes', 'url': 'http://twitter.com/search?q=%22Brenda+Snipes%22', 'promoted_content': None, 'query': '%22Brenda+Snipes%22', 'tweet_volume': None}, {'name': 'Daniel Johnson', 'url': 'http://twitter.com/search?q=%22Daniel+Johnson%22', 'promoted_content': None, 'query': '%22Daniel+Johnson%22', 'tweet_volume': None}, {'name': 'Nanih Waiya', 'url': 'http://twitter.com/search?q=%22Nanih+Waiya%22', 'promoted_content': None, 'query': '%22Nanih+Waiya%22', 'tweet_volume': None}, {'name': 'Jonathan Schoop', 'url': 'http://twitter.com/search?q=%22Jonathan+Schoop%22', 'promoted_content': None, 'query': '%22Jonathan+Schoop%22', 'tweet_volume': None}, {'name': 'Victor Oladipo', 'url': 'http://twitter.com/search?q=%22Victor+Oladipo%22', 'promoted_content': None, 'query': '%22Victor+Oladipo%22', 'tweet_volume': None}, {'name': 'throne 2', 'url': 'http://twitter.com/search?q=%22throne+2%22', 'promoted_content': None, 'query': '%22throne+2%22', 'tweet_volume': 26566}, {'name': 'Shelby Miller', 'url': 'http://twitter.com/search?q=%22Shelby+Miller%22', 'promoted_content': None, 'query': '%22Shelby+Miller%22', 'tweet_volume': None}, {'name': 'Brandon Knight', 'url': 'http://twitter.com/search?q=%22Brandon+Knight%22', 'promoted_content': None, 'query': '%22Brandon+Knight%22', 'tweet_volume': None}, {'name': 'Jeff Green', 'url': 'http://twitter.com/search?q=%22Jeff+Green%22', 'promoted_content': None, 'query': '%22Jeff+Green%22', 't ...

# %% [markdown]
# ## Example 3. Displaying API responses as pretty-printed JSON

# %%
import json

print((json.dumps(us_trends[:2], indent=1)))
# Out:
# [
#  {
#   "trends": [
#    {
#     "name": "#ThankUNextVideo",
#     "url": "http://twitter.com/search?q=%23ThankUNextVideo",
#     "promoted_content": null,
#     "query": "%23ThankUNextVideo",
#     "tweet_volume": 544478
#    },
#    {
#     "name": "Kareem Hunt",
#     "url": "http://twitter.com/search?q=%22Kareem+Hunt%22",
#     "promoted_content": null,
#     "query": "%22Kareem+Hunt%22",
#     "tweet_volume": 66940
#    },
#    {
#     "name": "#AskMeek",
#     "url": "http://twitter.com/search?q=%23AskMeek",
#     "promoted_content": null,
#     "query": "%23AskMeek",
#     "tweet_volume": null
#    },
#    {
#     "name": "Ariana Grande",
#     "url": "http://twitter.com/search?q=%22Ariana+Grande%22",
#     "promoted_content": null,
#     "query": "%22Ariana+Grande%22",
#     "tweet_volume": 239785
#    },
#    {
#     "name": "Anchorage",
#     "url": "http://twitter.com/search?q=Anchorage",
#     "promoted_content": null,
#     "query": "Anchorage",
#     "tweet_volume": 155357
#    },
#    {
#     "name": "Yan Gomes",
#     "url": "http://twitter.com/search?q=%22Yan+Gomes%22",
#     "promoted_content": null,
#     "query": "%22Yan+Gomes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#AlaskaEarthquake",
#     "url": "http://twitter.com/search?q=%23AlaskaEarthquake",
#     "promoted_content": null,
#     "query": "%23AlaskaEarthquake",
#     "tweet_volume": null
#    },
#    {
#     "name": "Wilmer Flores",
#     "url": "http://twitter.com/search?q=%22Wilmer+Flores%22",
#     "promoted_content": null,
#     "query": "%22Wilmer+Flores%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "#SagerStrong",
#     "url": "http://twitter.com/search?q=%23SagerStrong",
#     "promoted_content": null,
#     "query": "%23SagerStrong",
#     "tweet_volume": 11406
#    },
#    {
#     "name": "#RomComMyLife",
#     "url": "http://twitter.com/search?q=%23RomComMyLife",
#     "promoted_content": null,
#     "query": "%23RomComMyLife",
#     "tweet_volume": null
#    },
#    {
#     "name": "Amber Guyger",
#     "url": "http://twitter.com/search?q=%22Amber+Guyger%22",
#     "promoted_content": null,
#     "query": "%22Amber+Guyger%22",
#     "tweet_volume": 18511
#    },
#    {
#     "name": "Tim Means",
#     "url": "http://twitter.com/search?q=%22Tim+Means%22",
#     "promoted_content": null,
#     "query": "%22Tim+Means%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Tornado Watch",
#     "url": "http://twitter.com/search?q=%22Tornado+Watch%22",
#     "promoted_content": null,
#     "query": "%22Tornado+Watch%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Spencer Ware",
#     "url": "http://twitter.com/search?q=%22Spencer+Ware%22",
#     "promoted_content": null,
#     "query": "%22Spencer+Ware%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nick Ward",
#     "url": "http://twitter.com/search?q=%22Nick+Ward%22",
#     "promoted_content": null,
#     "query": "%22Nick+Ward%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "wayne estopinal",
#     "url": "http://twitter.com/search?q=%22wayne+estopinal%22",
#     "promoted_content": null,
#     "query": "%22wayne+estopinal%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Brenda Snipes",
#     "url": "http://twitter.com/search?q=%22Brenda+Snipes%22",
#     "promoted_content": null,
#     "query": "%22Brenda+Snipes%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Daniel Johnson",
#     "url": "http://twitter.com/search?q=%22Daniel+Johnson%22",
#     "promoted_content": null,
#     "query": "%22Daniel+Johnson%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Nanih Waiya",
#     "url": "http://twitter.com/search?q=%22Nanih+Waiya%22",
#     "promoted_content": null,
#     "query": "%22Nanih+Waiya%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jonathan Schoop",
#     "url": "http://twitter.com/search?q=%22Jonathan+Schoop%22",
#     "promoted_content": null,
#     "query": "%22Jonathan+Schoop%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Victor Oladipo",
#     "url": "http://twitter.com/search?q=%22Victor+Oladipo%22",
#     "promoted_content": null,
#     "query": "%22Victor+Oladipo%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "throne 2",
#     "url": "http://twitter.com/search?q=%22throne+2%22",
#     "promoted_content": null,
#     "query": "%22throne+2%22",
#     "tweet_volume": 26566
#    },
#    {
#     "name": "Shelby Miller",
#     "url": "http://twitter.com/search?q=%22Shelby+Miller%22",
#     "promoted_content": null,
#     "query": "%22Shelby+Miller%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Brandon Knight",
#     "url": "http://twitter.com/search?q=%22Brandon+Knight%22",
#     "promoted_content": null,
#     "query": "%22Brandon+Knight%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jeff Green",
#     "url": "http://twitter.com/search?q=%22Jeff+Green%22",
#     "promoted_content": null,
#     "query": "%22Jeff+Green%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Addison Russell",
#     "url": "http://twitter.com/search?q=%22Addison+Russell%22",
#     "promoted_content": null,
#     "query": "%22Addison+Russell%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Jada Byers",
#     "url": "http://twitter.com/search?q=%22Jada+Byers%22",
#     "promoted_content": null,
#     "query": "%22Jada+Byers%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Wichita Falls",
#     "url": "http://twitter.com/search?q=%22Wichita+Falls%22",
#     "promoted_content": null,
#     "query": "%22Wichita+Falls%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The RAC",
#     "url": "http://twitter.com/search?q=%22The+RAC%22",
#     "promoted_content": null,
#     "query": "%22The+RAC%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Hollywood Walk of Fame",
#     "url": "http://twitter.com/search?q=%22Hollywood+Walk+of+Fame%22",
#     "promoted_content": null,
#     "query": "%22Hollywood+Walk+of+Fame%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Former Dallas",
#     "url": "http://twitter.com/search?q=%22Former+Dallas%22",
#     "promoted_content": null,
#     "query": "%22Former+Dallas%22",
#     "tweet_volume": 11904
#    },
#    {
#     "name": "PJ Dozier",
#     "url": "http://twitter.com/search?q=%22PJ+Dozier%22",
#     "promoted_content": null,
#     "query": "%22PJ+Dozier%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "ICONIC",
#     "url": "http://twitter.com/search?q=ICONIC",
#     "promoted_content": null,
#     "query": "ICONIC",
#     "tweet_volume": 161785
#    },
#    {
#     "name": "Nicklas Backstrom",
#     "url": "http://twitter.com/search?q=%22Nicklas+Backstrom%22",
#     "promoted_content": null,
#     "query": "%22Nicklas+Backstrom%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "White Sox",
#     "url": "http://twitter.com/search?q=%22White+Sox%22",
#     "promoted_content": null,
#     "query": "%22White+Sox%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "The Indians",
#     "url": "http://twitter.com/search?q=%22The+Indians%22",
#     "promoted_content": null,
#     "query": "%22The+Indians%22",
#     "tweet_volume": null
#    },
#    {
#     "name": "Kesha",
#     "url": "http://twitter.com/search?q=Kesha",
#     "promoted_content": null,
#     "query": "Kesha",
#     "tweet_volume": 12591
#    },
#    {
#     "name": "Col\u00f3n",
#     "url": "http://twitter.com/search?q=Col%C3%B3n",
#     "promoted_content": null,
#     "query": "Col%C3%B3n",
#     "tweet_volume": 58930
#    },
#    {
#     "name": "#MACtion",
#     "url": "http://twitter.com/search?q=%23MACtion",
#     "promoted_content": null,
#     "query": "%23MACtion",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Pac12FCG",
#     "url": "http://twitter.com/search?q=%23Pac12FCG",
#     "promoted_content": null,
#     "query": "%23Pac12FCG",
#     "tweet_volume": null
#    },
#    {
#     "name": "#CapsDevils",
#     "url": "http://twitter.com/search?q=%23CapsDevils",
#     "promoted_content": null,
#     "query": "%23CapsDevils",
#     "tweet_volume": null
#    },
#    {
#     "name": "#LateLateToyShow",
#     "url": "http://twitter.com/search?q=%23LateLateToyShow",
#     "promoted_content": null,
#     "query": "%23LateLateToyShow",
#     "tweet_volume": 51511
#    },
#    {
#     "name": "#KIISJingleBall",
#     "url": "http://twitter.com/search?q=%23KIISJingleBall",
#     "promoted_content": null,
#     "query": "%23KIISJingleBall",
#     "tweet_volume": 14598
#    },
#    {
#     "name": "#StrangeJobPostings",
#     "url": "http://twitter.com/search?q=%23StrangeJobPostings",
#     "promoted_content": null,
#     "query": "%23StrangeJobPostings",
#     "tweet_volume": null
#    },
#    {
#     "name": "#ClimateFriday",
#     "url": "http://twitter.com/search?q=%23ClimateFriday",
#     "promoted_content": null,
#     "query": "%23ClimateFriday",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WCollegeCup",
#     "url": "http://twitter.com/search?q=%23WCollegeCup",
#     "promoted_content": null,
#     "query": "%23WCollegeCup",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Bellator210",
#     "url": "http://twitter.com/search?q=%23Bellator210",
#     "promoted_content": null,
#     "query": "%23Bellator210",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Redsfest",
#     "url": "http://twitter.com/search?q=%23Redsfest",
#     "promoted_content": null,
#     "query": "%23Redsfest",
#     "tweet_volume": null
#    },
#    {
#     "name": "#Dbacks",
#     "url": "http://twitter.com/search?q=%23Dbacks",
#     "promoted_content": null,
#     "query": "%23Dbacks",
#     "tweet_volume": null
#    },
#    {
#     "name": "#WhenISeeTheFirstSnowFlake",
#     "url": "http://twitter.com/search?q=%23WhenISeeTheFirstSnowFlake",
#     "promoted_content": null,
#     "query": "%23WhenISeeTheFirstSnowFlake",
#     "tweet_volume": null
#    }
#   ],
#   "as_of": "2018-12-01T00:27:55Z",
#   "created_at": "2018-12-01T00:21:44Z",
#   "locations": [
#    {
#     "name": "United States",
#     "woeid": 23424977
#    }
#   ]
#  }
# ]

# %% [markdown]
# ## Example 4. Computing the intersection of two sets of trends

# %%
trends_set = {}
trends_set['world'] = set([trend['name'] 
                        for trend in world_trends[0]['trends']])

trends_set['us'] = set([trend['name'] 
                     for trend in us_trends[0]['trends']]) 

trends_set['los angeles'] = set([trend['name'] 
                     for trend in local_trends[0]['trends']])

# %%
for loc in ['world','us','los angeles']:
    print(('-'*10,loc))
    print((','.join(trends_set[loc])))
# Out:
# ('----------', 'world')
# #BalanceTonPost,#ElMandamas,#ChadwickRenuncia,#SagerStrong,#ViernesDeEliminacion,#GrahamNorton,Tim Means,#ThankUNextVideo,#LateLateToyShow,#CARWOL,Wilmer Flores,#SchleFaZ,#HarryPotterEnCuatro,#اوصف_شعورك_بكلمه,#UnCuentoInfantilConDuque,#ウルトラマンルーブ,#propagandalive,#bakeoffitalia,#AMLOFest,Anchorage,#AskMeek,#CrownPrinceInG20,#G20Summit2018,#UltimoViernesDeMesY,#قمه_لقاء_محمد_بن_سلمان,Kareem Hunt,Amber Guyger,#PagaráPremiumSuMadre,Alaska,Julio Bocca,#MilenioLive,#ادعم_جروس,Colón,Matías Suárez,#ديسمبر,#EnDiciembreMeEspera,#RememberSKAM,#RomComMyLife,Yan Gomes,Sam Gyimah,#TCMS10,#TheVoiceKids,#平ジェネFOREVER,#هل_تنصحون_بالزواج_المبكر,Pinilla,#HotWheelsSebas,#scherziaparte,Flavia Palmiero,#AsAventurasDePoliana143,#ASSEFCN
# ('----------', 'us')
# #KIISJingleBall,Jeff Green,Jada Byers,#SagerStrong,Kesha,Daniel Johnson,#Pac12FCG,#Bellator210,Tim Means,#ThankUNextVideo,#WhenISeeTheFirstSnowFlake,#LateLateToyShow,The RAC,White Sox,#WCollegeCup,Wilmer Flores,throne 2,Ariana Grande,Wichita Falls,Anchorage,#AskMeek,#Dbacks,#AlaskaEarthquake,Kareem Hunt,ICONIC,#ClimateFriday,Amber Guyger,Brenda Snipes,Victor Oladipo,Addison Russell,Brandon Knight,Hollywood Walk of Fame,#Redsfest,Colón,Nick Ward,#MACtion,Nicklas Backstrom,#RomComMyLife,Spencer Ware,Yan Gomes,PJ Dozier,#CapsDevils,Jonathan Schoop,Former Dallas,#StrangeJobPostings,Tornado Watch,The Indians,wayne estopinal,Nanih Waiya,Shelby Miller
# ('----------', 'los angeles')
# #KIISJingleBall,Jeff Green,Jada Byers,#SagerStrong,Kesha,Daniel Johnson,#Pac12FCG,#Bellator210,Tim Means,#ThankUNextVideo,#WhenISeeTheFirstSnowFlake,#LateLateToyShow,The RAC,Nick Nolte,White Sox,#WCollegeCup,Wilmer Flores,throne 2,Ariana Grande,Wichita Falls,Anchorage,#AskMeek,#Dbacks,#AlaskaEarthquake,Kareem Hunt,ICONIC,#ClimateFriday,Amber Guyger,Brenda Snipes,Victor Oladipo,Addison Russell,Brandon Knight,Hollywood Walk of Fame,#Redsfest,Colón,#MACtion,Nicklas Backstrom,#RomComMyLife,Spencer Ware,Yan Gomes,PJ Dozier,#CapsDevils,Jonathan Schoop,Former Dallas,#StrangeJobPostings,Tornado Watch,The Indians,wayne estopinal,Nanih Waiya,Shelby Miller

# %%
print(( '='*10,'intersection of world and us'))
print((trends_set['world'].intersection(trends_set['us'])))

print(('='*10,'intersection of us and san-diego'))
print((trends_set['los angeles'].intersection(trends_set['us'])))
# Out:
# ('==========', 'intersection of world and us')
# {'#RomComMyLife', 'Amber Guyger', 'Yan Gomes', '#SagerStrong', 'Tim Means', '#ThankUNextVideo', '#LateLateToyShow', 'Anchorage', '#AskMeek', 'Colón', 'Kareem Hunt', 'Wilmer Flores'}
# ('==========', 'intersection of us and san-diego')
# {'#KIISJingleBall', 'Jeff Green', 'Jada Byers', '#SagerStrong', 'Kesha', 'Daniel Johnson', '#Pac12FCG', '#Bellator210', 'Tim Means', '#ThankUNextVideo', '#WhenISeeTheFirstSnowFlake', '#LateLateToyShow', 'White Sox', '#WCollegeCup', 'throne 2', 'Wilmer Flores', 'Ariana Grande', 'Wichita Falls', 'Anchorage', '#AskMeek', '#Dbacks', '#AlaskaEarthquake', 'Kareem Hunt', 'ICONIC', '#ClimateFriday', 'Amber Guyger', 'Brenda Snipes', 'Victor Oladipo', 'Addison Russell', 'Brandon Knight', 'Hollywood Walk of Fame', '#Redsfest', 'wayne estopinal', 'Colón', '#MACtion', 'Nicklas Backstrom', '#RomComMyLife', 'Spencer Ware', 'Yan Gomes', 'PJ Dozier', '#CapsDevils', 'Jonathan Schoop', 'Former Dallas', '#StrangeJobPostings', 'Tornado Watch', 'The Indians', 'The RAC', 'Nanih Waiya', 'Shelby Miller'}

# %% [markdown]
# ## Example 5. Collecting search results

# %% [markdown]
# Set the variable `q` to a trending topic,
# or anything else for that matter. The example query below
# was a trending topic when this content was being developed
# and is used throughout the remainder of this chapter

# %%
q = '#FelizMiércoles'

number = 100

# See https://dev.twitter.com/docs/api/1.1/get/search/tweets

search_results = twitter_api.search.tweets(q=q, count=number)

statuses = search_results['statuses']

# %%
len(statuses)
#print(statuses)
# Out:
# 56

# %% [markdown]
# Twitter often returns duplicate results, we can filter them out checking for duplicate texts:

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
statuses = filtered_statuses

# %%
len(statuses)
# Out:
# 51

# %%
[s['text'] for s in search_results['statuses']]
# Out:
# ['RT @sumalen59: Buenos días a tod@s! #FelizMiércoles republicano!Preparándonos para tuitear con el HT de @MiercolesRepub1 Si tienes ganas de…',
#  'RT @jdavidcabello: #FelizMiércoles hoy continuamos trabajando por nuestra Patria, la de Bolívar y Chávez, hombres que lucharon contra opres…',
#  'RT @PeterPeterbox: «El ciclismo es para todos». Bernard Hinault \n\n#VivaLaBici  #bicicleta  #labicimola  #FelizMiércoles\n¿Vamos a coger las…',
#  'RT @zaidacastillo51: 🐘🌾🌷🍀 🌺🍀🐘\n¡Buenos días mundo twittero!!\n\n"Que tu meta de hoy sea... \nganarle la batalla a tu mejor excusa..."\n\n#Elefant…',
#  'RT @Mayesocialista: #FelizMiércoles Patria amada, afinando los últimos detalles para iniciar en unos minutos el ciclo de ponencias del Cong…',
#  'RT @nisiu07: Uno pertenece a donde\nSe le quiere,se le desea,se le ama\nY en repetidas ocasiones\n" se le extraña "\nPero sobre todo\nA donde se…',
#  'RT @LosChamosMx: #FelizMiércoles ya probaste nuestro pasticho? https://t.co/nY1rNhQgYt',
#  'RT @LeyreArgenta: (\\__/)\n(=\'.\'=)\nE[:]|||||[:]З\n(")_(") \n  Buenos días mundo 🎄\n\n#FelizDia\n#FelizMiercoles',
#  'RT @laspancheritas: ¡Hola a tod@s! Estamos felices porque Pancho ya está en su natal Argentina 🇦🇷 donde está rodeado de mucho amor y cariño…',
#  'RT @MariaIranzoBio: La spirulina puede atacar a las células tumorales espontáneamente y sin dañar a las sanas… ¡Una nueva herramienta nanot…',
#  'RT @SoyardEcu: Es hora del #RetoSoyard de esta semana! 😯💡\nRecuerda que Soyard es rico en omega 3, 6 y 9 lo cual te ayuda a fortalecer tu sa…',
#  'RT @fodenorca: #Ahora 📢| Se desarrolla la creación del CT49 Cuero, calzados y afines para normalizar este rubro y velar por la calidad que…',
#  'RT @Mippcivzla: #FelizMiércoles Buenos días te presentamos las portadas de los diarios🗞 que circulan la mañana de hoy #28Nov. https://t.co/…',
#  'RT @Reportes360: #TránsitoCCS ¡FELIZ MIÉRCOLES! Iniciamos desde la Valle-Coche donde hay libre desplazamiento para conectar con la #AFF. Se…',
#  'RT @pazinteriorv: NAMASTÉ🙏🍀\nFeliz Miércoles! 💝\nHappy Wednesday!\n #love #Paz #FelizMiércoles #meditation #frases #Mindfulness #WednesdayWisd…',
#  'RT @Region3Policia: ¡Nuestra actitud de servicio es reconocida por la ciudadanía! \nhttps://t.co/LefZmEicV8 \n@PoliciaColombia @PoliciaPereir…',
#  'Parece mentira que con la app gratuita de #Kindle puedas leer tantas novelas y relatos eróticos en tu móvil. En… https://t.co/xw6MlACe0D',
#  'RT @vmm7773: Dice Casado que en España “no hay sitio para el que viene a delinquir”\n\nEso significa ... ¿Que van a ser expulsados de nuestro…',
#  'RT @abelhuitron: Marketing digital, educación, seguridad en internet y liderazgo femenino, son algunos de los temas que se están abordando…',
#  'RT @EmergenciasMad: En una situación de #Emergencia hay que guardar la calma y ayudar a quienes lo tienen más difícil. No cuesta nada apren…',
#  'RT @DMZenvios: En @DMZcomputer les deseamos un muy #felizmiercoles https://t.co/dRpnpCNTeJ',
#  'RT @DMZenvios: En @DMZcomputer les deseamos un muy #felizmiercoles https://t.co/H55pLVC5Zd',
#  'RT @PrimosMX: Hay que dejar ir y dejarse llevar a veces para vivir y disfrutar 😘😅😁🤘💪 !!\n#PurosPrimos #PrimosMx #LosPrimosMx20Aniversario \n🎶…',
#  'RT @RPuntoSobreLai: #FelizMiércoles @juanantonio6289 habla sobre el amor y las relaciones en pareja en su entrevista en #Teleformula y en s…',
#  'RT @HdAnchiano: Artesanía con forma de moneda y precisión de relojero. #FelizMiércoles https://t.co/Cvr0vnnSOr',
#  'RT @mymarbellaochoa: La paz empieza en nuestros corazones y el amor a lo niños es reflejo de esta paz #RETOFEPAZ #ViralizaLaPaz #RETOFEPAZ…',
#  'RT @ABC760AM: ¿Sera tu día de suerte? 🔮Descúbrelo leyendo tu #HoroscopoDeHoy ♍♌♈\n\n➡ https://t.co/koBODDz68n\n\n#FelizMiercoles https://t.co/f…',
#  'RT @ABC760AM: 📰#BuenosDías, hoy #EnPortada de @laprensaoem   \n               ¡CHAPO FIFÍ!\n⬇️Lee La Prensa en Línea ⬇️\nhttps://t.co/IUHq61Yx…',
#  'RT @jdavidcabello: #FelizMiércoles hoy continuamos trabajando por nuestra Patria, la de Bolívar y Chávez, hombres que lucharon contra opres…',
#  'RT @FuerzaAereaCol: #FelizMiércoles ➡ Por surcar a diario los cielos colombianos, somos testigos de un amanecer libre y un anochecer sobera…',
#  'RT @premiumflorist: ¡Encontraron agua en Marte! 😯 ¿Y sabes qué? 🤔 ¡Contigo voy a Marte y a cualquier otra parte! 👽👫💖\n\n#FelizMiercoles',
#  'RT @LeyreArgenta: (\\__/)\n(=\'.\'=)\nE[:]|||||[:]З\n(")_(") \n  Buenos días mundo 🎄\n\n#FelizDia\n#FelizMiercoles',
#  'RT @premiumflorist: ¡Truco o trato! 🍬 Que esta noche funcionen todos tus hechizos de amor y felicidad 💖 ¡Feliz Halloween! 🎃\n\n#HappyHallowee…',
#  'RT @lverboencarnado: No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/wZ8008KIYS',
#  'RT @SevillaEsconde: En el centro de la Plaza Nueva se levanta desde 1924 el monumento al rey Fernando III, conocido como El Santo. Fue el c…',
#  'RT @lverboencarnado: No hay #PretextosParaNoIr y participar de la #SantaMisa este #FelizMiércoles 28 noviembre 2018 https://t.co/VfDimJrG0M',
#  "RT @FMacias_: ¡No queda nada para '1016'! Felicidades por este sueño que ya es realidad y del que nos has hecho partícipe desde el inicio.…",
#  'RT @lverboencarnado: No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/oYXOUjHm65',
#  'RT @lverboencarnado: No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/wZ8008KIYS',
#  'RT @lverboencarnado: No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/3e7G466vTJ',
#  'RT @lverboencarnado: No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/00H3Gi0XJc',
#  'RT @lverboencarnado: No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/xRsL2CDOrA',
#  'RT @lverboencarnado: No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/jLZNhT2x4S',
#  'RT @s_um_mer0: 🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀\n🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳\n#quote Hay palabras que de tanto repetirlas pierden el sentido. #HappyWednesday #FelizMiercole…',
#  'RT @1bloggerist: how confident are you\n👇\nhttps://t.co/hOVfsxT3oW\n\n#WorldsMostBeautifulBride #ShahOnAajTak #DevendraWithMaratha #LadiesSpeci…',
#  'RT @1bloggerist: The secret of success: self-confidence\n👇\nhttps://t.co/hOVfsxT3oW\n\n#WorldsMostBeautifulBride #ShahOnAajTak #DevendraWithMar…',
#  'RT @revista_lux_dei: #FelizMiercoles https://t.co/YblfDMYI6u',
#  'RT @VOX_Jaen: Así ha aparecido la puerta de nuestra sede en #JAEN esta mañana.\nNo se enteran. Cosas como éstas nos dan más fuerzas para lle…',
#  'RT @abelhuitron: Marketing digital, educación, seguridad en internet y liderazgo femenino, son algunos de los temas que se están abordando…',
#  'RT @GearsLATAM: Momentos irrespetuosos de Gears 2.\n\n#PretextosParaNoIr sin casco a la batalla, por Ben Carmine:\nCon casco no respiras polvo…',
#  'RT @HectorSulaimanS: “No es héroe quien carece de miedos. Un héroe es quien lo siente, lo enfrenta y lo supera.”…',
#  'RT @vmm7773: Dice Casado que en España “no hay sitio para el que viene a delinquir”\n\nEso significa ... ¿Que van a ser expulsados de nuestro…',
#  'RT @Carloschuchero: @jucilnacional #EnEstaFamiliaNadieLuchaSolo  gracias @jucilnacional  por apoyar lo que es justo para los compañeros. Si…',
#  'RT @s_um_mer0: ❄🌬❄🌬❄🌬❄🌬❄🌬❄🌬❄🌬🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌\n#HappyWednesday #FelizMiércoles \n🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲❄❄❄❄❄❄❄❄❄❄❄❄❄❄ https://t.co/VyX1IHeNkr',
#  'No hay #PretextosParaNoIr a rezar el #SantoRosario este #FelizMiércoles 28 noviembre 2018 https://t.co/00H3Gi0XJc',
#  'RT @lucha_gr: #FelizMiércoles #España #Andalucía #EleccionesAndaluzas #2D https://t.co/NnCjlXCE5C']

# %%
# Show one sample search result by slicing the list...
print(json.dumps(statuses[0], indent=1))
# Out:
# {
#  "created_at": "Sat Dec 01 00:27:00 +0000 2018",
#  "id": 1068662713679822848,
#  "id_str": "1068662713679822848",
#  "text": "RT @sumalen59: Buenos d\u00edas a tod@s! #FelizMi\u00e9rcoles republicano!Prepar\u00e1ndonos para tuitear con el HT de @MiercolesRepub1 Si tienes ganas de\u2026",
#  "truncated": false,
#  "entities": {
#   "hashtags": [
#    {
#     "text": "FelizMi\u00e9rcoles",
#     "indices": [
#      36,
#      51
#     ]
#    }
#   ],
#   "symbols": [],
#   "user_mentions": [
#    {
#     "screen_name": "sumalen59",
#     "name": "SusanneML#Paz\ud83c\udf97",
#     "id": 583043908,
#     "id_str": "583043908",
#     "indices": [
#      3,
#      13
#     ]
#    },
#    {
#     "screen_name": "MiercolesRepub1",
#     "name": "Mi\u00e9rcoles Republicano \u2764\ud83d\udc9b\ud83d\udc9c",
#     "id": 1021561931856048128,
#     "id_str": "1021561931856048128",
#     "indices": [
#      104,
#      120
#     ]
#    }
#   ],
#   "urls": []
#  },
#  "metadata": {
#   "iso_language_code": "es",
#   "result_type": "recent"
#  },
#  "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#  "in_reply_to_status_id": null,
#  "in_reply_to_status_id_str": null,
#  "in_reply_to_user_id": null,
#  "in_reply_to_user_id_str": null,
#  "in_reply_to_screen_name": null,
#  "user": {
#   "id": 1339760053,
#   "id_str": "1339760053",
#   "name": "Alberto",
#   "screen_name": "Algonfdez",
#   "location": "",
#   "description": "",
#   "url": null,
#   "entities": {
#    "description": {
#     "urls": []
#    }
#   },
#   "protected": false,
#   "followers_count": 3683,
#   "friends_count": 5000,
#   "listed_count": 365,
#   "created_at": "Tue Apr 09 17:31:21 +0000 2013",
#   "favourites_count": 8724,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": true,
#   "verified": false,
#   "statuses_count": 730003,
#   "lang": "es",
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "C0DEED",
#   "profile_background_image_url": "http://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme1/bg.png",
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/717628086955741184/zAKN6J0L_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/717628086955741184/zAKN6J0L_normal.jpg",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": false,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
#  },
#  "geo": null,
#  "coordinates": null,
#  "place": null,
#  "contributors": null,
#  "retweeted_status": {
#   "created_at": "Wed Nov 28 06:18:34 +0000 2018",
#   "id": 1067664024505118720,
#   "id_str": "1067664024505118720",
#   "text": "Buenos d\u00edas a tod@s! #FelizMi\u00e9rcoles republicano!Prepar\u00e1ndonos para tuitear con el HT de @MiercolesRepub1 Si tienes\u2026 https://t.co/dG9bjmdIwa",
#   "truncated": true,
#   "entities": {
#    "hashtags": [
#     {
#      "text": "FelizMi\u00e9rcoles",
#      "indices": [
#       21,
#       36
#      ]
#     }
#    ],
#    "symbols": [],
#    "user_mentions": [
#     {
#      "screen_name": "MiercolesRepub1",
#      "name": "Mi\u00e9rcoles Republicano \u2764\ud83d\udc9b\ud83d\udc9c",
#      "id": 1021561931856048128,
#      "id_str": "1021561931856048128",
#      "indices": [
#       89,
#       105
#      ]
#     }
#    ],
#    "urls": [
#     {
#      "url": "https://t.co/dG9bjmdIwa",
#      "expanded_url": "https://twitter.com/i/web/status/1067664024505118720",
#      "display_url": "twitter.com/i/web/status/1\u2026",
#      "indices": [
#       117,
#       140
#      ]
#     }
#    ]
#   },
#   "metadata": {
#    "iso_language_code": "es",
#    "result_type": "recent"
#   },
#   "source": "<a href=\"http://twitter.com/download/android\" rel=\"nofollow\">Twitter for Android</a>",
#   "in_reply_to_status_id": null,
#   "in_reply_to_status_id_str": null,
#   "in_reply_to_user_id": null,
#   "in_reply_to_user_id_str": null,
#   "in_reply_to_screen_name": null,
#   "user": {
#    "id": 583043908,
#    "id_str": "583043908",
#    "name": "SusanneML#Paz\ud83c\udf97",
#    "screen_name": "sumalen59",
#    "location": "Valencia",
#    "description": "Me gusta la gente sentipensante,que no separa la raz\u00f3n del coraz\u00f3n...(Galeano)\nS\u00e9 la persona que tu perro piensa q eres.\nParticipo en @miercolesrepub1 21h\u2764\ud83d\udc9b\ud83d\udc9c",
#    "url": null,
#    "entities": {
#     "description": {
#      "urls": []
#     }
#    },
#    "protected": false,
#    "followers_count": 13662,
#    "friends_count": 11363,
#    "listed_count": 126,
#    "created_at": "Thu May 17 19:00:39 +0000 2012",
#    "favourites_count": 121642,
#    "utc_offset": null,
#    "time_zone": null,
#    "geo_enabled": true,
#    "verified": false,
#    "statuses_count": 196342,
#    "lang": "es",
#    "contributors_enabled": false,
#    "is_translator": false,
#    "is_translation_enabled": false,
#    "profile_background_color": "B2DFDA",
#    "profile_background_image_url": "http://abs.twimg.com/images/themes/theme13/bg.gif",
#    "profile_background_image_url_https": "https://abs.twimg.com/images/themes/theme13/bg.gif",
#    "profile_background_tile": false,
#    "profile_image_url": "http://pbs.twimg.com/profile_images/881925064794427394/0L45VgIq_normal.jpg",
#    "profile_image_url_https": "https://pbs.twimg.com/profile_images/881925064794427394/0L45VgIq_normal.jpg",
#    "profile_banner_url": "https://pbs.twimg.com/profile_banners/583043908/1360407962",
#    "profile_link_color": "93A644",
#    "profile_sidebar_border_color": "EEEEEE",
#    "profile_sidebar_fill_color": "FFFFFF",
#    "profile_text_color": "333333",
#    "profile_use_background_image": true,
#    "has_extended_profile": false,
#    "default_profile": false,
#    "default_profile_image": false,
#    "following": false,
#    "follow_request_sent": false,
#    "notifications": false,
#    "translator_type": "none"
#   },
#   "geo": null,
#   "coordinates": null,
#   "place": null,
#   "contributors": null,
#   "is_quote_status": false,
#   "retweet_count": 90,
#   "favorite_count": 86,
#   "favorited": false,
#   "retweeted": false,
#   "possibly_sensitive": false,
#   "lang": "es"
#  },
#  "is_quote_status": false,
#  "retweet_count": 90,
#  "favorite_count": 0,
#  "favorited": false,
#  "retweeted": false,
#  "lang": "es"
# }

# %%
# The result of the list comprehension is a list with only one element that
# can be accessed by its index and set to the variable t
t = statuses[0]
#[ status for status in statuses 
#          if status['id'] == 316948241264549888 ][0]

# Explore the variable t to get familiarized with the data structure...

print(t['retweet_count'])
print(t['retweeted'])
# Out:
# 90
# False

# %% [markdown]
# ## Example 6. Extracting text, screen names, and hashtags from tweets

# %%
status_texts = [ status['text'] 
                 for status in statuses ]

screen_names = [ user_mention['screen_name'] 
                 for status in statuses
                     for user_mention in status['entities']['user_mentions'] ]

hashtags = [ hashtag['text'] 
             for status in statuses
                 for hashtag in status['entities']['hashtags'] ]

# Compute a collection of all words from all tweets
words = [ w 
          for t in status_texts 
              for w in t.split() ]

# %%
# Explore the first 5 items for each...

print(json.dumps(status_texts[0:5], indent=1))
print(json.dumps(screen_names[0:5], indent=1)) 
print(json.dumps(hashtags[0:5], indent=1))
print(json.dumps(words[0:5], indent=1))
# Out:
# [
#  "RT @sumalen59: Buenos d\u00edas a tod@s! #FelizMi\u00e9rcoles republicano!Prepar\u00e1ndonos para tuitear con el HT de @MiercolesRepub1 Si tienes ganas de\u2026",
#  "RT @jdavidcabello: #FelizMi\u00e9rcoles hoy continuamos trabajando por nuestra Patria, la de Bol\u00edvar y Ch\u00e1vez, hombres que lucharon contra opres\u2026",
#  "RT @PeterPeterbox: \u00abEl ciclismo es para todos\u00bb. Bernard Hinault \n\n#VivaLaBici  #bicicleta  #labicimola  #FelizMi\u00e9rcoles\n\u00bfVamos a coger las\u2026",
#  "RT @zaidacastillo51: \ud83d\udc18\ud83c\udf3e\ud83c\udf37\ud83c\udf40 \ud83c\udf3a\ud83c\udf40\ud83d\udc18\n\u00a1Buenos d\u00edas mundo twittero!!\n\n\"Que tu meta de hoy sea... \nganarle la batalla a tu mejor excusa...\"\n\n#Elefant\u2026",
#  "RT @Mayesocialista: #FelizMi\u00e9rcoles Patria amada, afinando los \u00faltimos detalles para iniciar en unos minutos el ciclo de ponencias del Cong\u2026"
# ]
# [
#  "sumalen59",
#  "MiercolesRepub1",
#  "jdavidcabello",
#  "PeterPeterbox",
#  "zaidacastillo51"
# ]
# [
#  "FelizMi\u00e9rcoles",
#  "FelizMi\u00e9rcoles",
#  "VivaLaBici",
#  "bicicleta",
#  "labicimola"
# ]
# [
#  "RT",
#  "@sumalen59:",
#  "Buenos",
#  "d\u00edas",
#  "a"
# ]

# %% [markdown]
# ## Example 7. Creating a basic frequency distribution from the words in tweets

# %%
from collections import Counter

for item in [words, screen_names, hashtags]:
    c = Counter(item)
    print(c.most_common()[:10]) # top 10
    print()
# Out:
# [('RT', 49), ('de', 26), ('a', 24), ('y', 21), ('#FelizMiércoles', 20), ('el', 17), ('en', 15), ('la', 14), ('que', 13), ('hay', 11)]
#
# [('lverboencarnado', 7), ('DMZenvios', 2), ('DMZcomputer', 2), ('ABC760AM', 2), ('premiumflorist', 2), ('s_um_mer0', 2), ('1bloggerist', 2), ('jucilnacional', 2), ('sumalen59', 1), ('MiercolesRepub1', 1)]
#
# [('FelizMiércoles', 20), ('PretextosParaNoIr', 9), ('SantoRosario', 7), ('FelizMiercoles', 4), ('felizmiercoles', 2), ('RETOFEPAZ', 2), ('HappyWednesday', 2), ('WorldsMostBeautifulBride', 2), ('ShahOnAajTak', 2), ('VivaLaBici', 1)]

# %% [markdown]
# ## Example 8. Create a prettyprint function to display tuples in a nice tabular format

# %%
def prettyprint_counts(label, list_of_tuples):
    print("\n{:^20} | {:^6}".format(label, "Count"))
    print("*"*40)
    for k,v in list_of_tuples:
        print("{:20} | {:>6}".format(k,v))

# %%
for label, data in (('Word', words), 
                    ('Screen Name', screen_names), 
                    ('Hashtag', hashtags)):
    
    c = Counter(data)
    prettyprint_counts(label, c.most_common()[:10])
# Out:
#         Word         | Count
# ****************************************
# RT                   |     49
# de                   |     26
# a                    |     24
# y                    |     21
# #FelizMiércoles      |     20
# el                   |     17
# en                   |     15
# la                   |     14
# que                  |     13
# hay                  |     11
#
#     Screen Name      | Count
# ****************************************
# lverboencarnado      |      7
# DMZenvios            |      2
# DMZcomputer          |      2
# ABC760AM             |      2
# premiumflorist       |      2
# s_um_mer0            |      2
# 1bloggerist          |      2
# jucilnacional        |      2
# sumalen59            |      1
# MiercolesRepub1      |      1
#
#       Hashtag        | Count
# ****************************************
# FelizMiércoles       |     20
# PretextosParaNoIr    |      9
# SantoRosario         |      7
# FelizMiercoles       |      4
# felizmiercoles       |      2
# RETOFEPAZ            |      2
# HappyWednesday       |      2
# WorldsMostBeautifulBride |      2
# ShahOnAajTak         |      2
# VivaLaBici           |      1

# %% [markdown]
# ## Example 9. Finding the most popular retweets

# %%
retweets = [
            # Store out a tuple of these three values ...
            (status['retweet_count'], 
             status['retweeted_status']['user']['screen_name'],
             status['text'].replace("\n","\\")) 
            
            # ... for each status ...
            for status in statuses 
            
            # ... so long as the status meets this condition.
                if 'retweeted_status' in status
           ]

# %% [markdown]
# We can build another `prettyprint` function to print entire tweets with their retweet count.
#
# We also want to split the text of the tweet in up to 3 lines, if needed.

# %%
row_template = "{:^7} | {:^15} | {:50}"
def prettyprint_tweets(list_of_tuples):
    print()
    print(row_template.format("Count", "Screen Name", "Text"))
    print("*"*80)
    for count, screen_name, text in list_of_tuples:
        print(row_template.format(count, screen_name, text[:50]))
        if len(text) > 50:
            print(row_template.format("", "", text[50:100]))
            if len(text) > 100:
                print(row_template.format("", "", text[100:]))

# %%
# Slice off the first 5 from the sorted results and display each item in the tuple

prettyprint_tweets(sorted(retweets, reverse=True)[:10])
# Out:
#  Count  |   Screen Name   | Text
# ********************************************************************************
#  2147   |     vmm7773     | RT @vmm7773: Dice Casado que en España “no hay sit
#         |                 | io para el que viene a delinquir”\\Eso significa .
#         |                 | .. ¿Que van a ser expulsados de nuestro…
#  1838   |   HdAnchiano    | RT @HdAnchiano: Artesanía con forma de moneda y pr
#         |                 | ecisión de relojero. #FelizMiércoles https://t.co/
#         |                 | Cvr0vnnSOr
#   699   |    s_um_mer0    | RT @s_um_mer0: ❄🌬❄🌬❄🌬❄🌬❄🌬❄🌬❄🌬🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌🦌\#Happy
#         |                 | Wednesday #FelizMiércoles \🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲🌲❄❄❄❄❄❄❄❄❄
#         |                 | ❄❄❄❄❄ https://t.co/VyX1IHeNkr
#   379   |  jdavidcabello  | RT @jdavidcabello: #FelizMiércoles hoy continuamos
#         |                 |  trabajando por nuestra Patria, la de Bolívar y Ch
#         |                 | ávez, hombres que lucharon contra opres…
#   320   | HectorSulaimanS | RT @HectorSulaimanS: “No es héroe quien carece de
#         |                 | miedos. Un héroe es quien lo siente, lo enfrenta y
#         |                 |  lo supera.”…
#   259   |    VOX_Jaen     | RT @VOX_Jaen: Así ha aparecido la puerta de nuestr
#         |                 | a sede en #JAEN esta mañana.\No se enteran. Cosas
#         |                 | como éstas nos dan más fuerzas para lle…
#   253   |    FMacias_     | RT @FMacias_: ¡No queda nada para '1016'! Felicida
#         |                 | des por este sueño que ya es realidad y del que no
#         |                 | s has hecho partícipe desde el inicio.…
#   127   | EmergenciasMad  | RT @EmergenciasMad: En una situación de #Emergenci
#         |                 | a hay que guardar la calma y ayudar a quienes lo t
#         |                 | ienen más difícil. No cuesta nada apren…
#   120   |    s_um_mer0    | RT @s_um_mer0: 🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀🍀\🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳🌳\#quot
#         |                 | e Hay palabras que de tanto repetirlas pierden el
#         |                 | sentido. #HappyWednesday #FelizMiercole…
#   104   |   Mippcivzla    | RT @Mippcivzla: #FelizMiércoles Buenos días te pre
#         |                 | sentamos las portadas de los diarios🗞 que circulan
#         |                 |  la mañana de hoy #28Nov. https://t.co/…
